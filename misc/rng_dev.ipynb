# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
from astropy import units as u
from astropy.time import Time
import scipy

import setigen as stg

import logging

# %%
# %matplotlib inline

# %%
rng = np.random.default_rng(0)
rng.normal(0, 1, 10)
# Out:
# array([ 0.12573022, -0.13210486,  0.64042265,  0.10490012, -0.53566937,
#         0.36159505,  1.30400005,  0.94708096, -0.70373524, -1.26542147])

# %%
2**20
# Out:
# 1048576

# %%
pfb = stg.voltage.PolyphaseFilterbank(num_taps=8, 
                                      num_branches=1024)
x = pfb.get_response(fftlength=64)
plt.plot(x)
plt.show()

plt.plot(pfb.tile_response(64, fftlength=2**12))
plt.show()

# %%
x.shape
# Out:
# (32,)

# %%
8*64/2
# Out:
# 256.0

# %%
64*8
# Out:
# 512

# %%
rng = np.random.default_rng()
rng.integers(0, 1024)
# Out:
# 947
