# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import blimpy as bl
import pandas as pd
from astropy import units as u

import sys, os, glob, errno
import csv
import json
import h5py
import time
from astropy.stats import sigma_clip


from scipy.signal import butter, lfilter, filtfilt
import scipy.signal

sys.path.insert(0, "/home/bryanb/setigen/")
import setigen as stg

def db(x):
    """ Convert linear value to dB value """
    return 10*np.log10(x)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !ls /datax/scratch/bbrzycki/data/raw_files/
# Out:
# blc00_guppi_59114_15868_TMC1_0010.0000.raw	    test_5min.0007.raw
# blc00_guppi_59114_15868_TMC1_0010.0013.raw	    test_5min.0008.raw
# blc00_guppi_59114_15868_TMC1_0010.rawspec.0000.fil  test_5min.0009.raw
# test_5min.0000.raw				    test_5min.0010.raw
# test_5min.0001.raw				    test_5min.0011.raw
# test_5min.0002.raw				    test_5min.0012.raw
# test_5min.0003.raw				    test_5min.0013.raw
# test_5min.0004.raw				    test_5min.rawspec.0000.fil
# test_5min.0005.raw				    test_5min.rawspec.0001.fil
# test_5min.0006.raw				    test_5min.rawspec.0002.fil

# %%
wf = bl.Waterfall('/datax/scratch/bbrzycki/data/raw_files/test_5min.rawspec.0000.fil',
                  f_start=0,
                  f_stop=187.5 / 64 * 3.5)
wf.plot_waterfall()
